# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from torchvision.utils import save_image

# %%
# Define Hyperperameters
image_size = 784
hidden_dim = 400
latent_dim = 20
batch_size = 128
epochs = 50

#Check GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#MNIST Dataset

train_dataset = torchvision.datasets.MNIST(root='../../data', 
                                           train=True, 
                                           download=True, 
                                           transform=transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_dataset = torchvision.datasets.MNIST(root='../../data', 
                                           train=False, 
                                           download=True, 
                                           transform=transforms.ToTensor())
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

# Create a Directory to save the reconstructed and sampled images (if directory not present)
PATH = '/content/drive/My Drive/Deep_Learning_Udemy/VAE/'
sample_dir = PATH+str('results')
if not os.path.exists(sample_dir):
  os.makedirs(sample_dir)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../../data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/train-images-idx3-ubyte.gz to ../../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../../data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../../data/MNIST/raw
# Processing...
#
#
#
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.

# %%
#VAE Model

class VAE(nn.Module):
  def __init__(self):
    super(VAE, self).__init__()

    self.fc1 = nn.Linear(image_size, hidden_dim)
    self.fc2_mean = nn.Linear(hidden_dim, latent_dim)
    self.fc2_logvar = nn.Linear(hidden_dim, latent_dim)
    self.fc3 = nn.Linear(latent_dim, hidden_dim)
    self.fc4 = nn.Linear(hidden_dim, image_size)

  def encode(self, x):
    h = F.relu(self.fc1(x))
    mu = self.fc2_mean(h)
    logvar = self.fc2_logvar(h)
    return mu, logvar

  def reparameterize(self, mu, logvar):
    std = torch.exp(logvar)
    eps = torch.randn_like(std)

    return mu + std * eps
  
  def decode(self, z):
    h = F.relu(self.fc3(z))
    out = torch.sigmoid(self.fc4(h))
    return out

  def forward(self, x):
    mu, logvar = self.encode(x.view(-1, image_size))
    z = self.reparameterize(mu, logvar)
    reconstructed = self.decode(z)
    return reconstructed, mu, logvar

# %%
  # Define model and optimizer
  model = VAE().to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)

# %%
# Define Loss
def loss_function(reconstructed_image, original_image, mu, logvar):
  bce = F.binary_cross_entropy(reconstructed_image, original_image.view(-1, 784), reduction='sum')
  kld = 0.5 * torch.sum(logvar.exp() + mu.pow(2) - 1 - logvar)
  return bce + kld

# %%
# Train function
def train(epoch):
  model.train()
  train_loss = 0
  for i, (images, _ )in enumerate(train_loader):
    images = images.to(device)
    reconstructed, mu, logvar = model(images)
    loss = loss_function(reconstructed, images, mu, logvar)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    train_loss += loss.item()

    if i % 100 == 0:
      print("Training epochs: {} [Batch {}/{}]\tLoss: {:.3f}".format(epoch, i, len(train_loader), loss.item() / len(images)))
    
  print("==========================>Epochs {}, Average Loss for Training: {:.3f}".format(epoch, train_loss/ len(train_loader.dataset)))

# %%
# Test function
def test(epoch):
  model.eval()
  test_loss = 0
  for batch_idx, (images, _ )in enumerate(test_loader):
    images = images.to(device)
    reconstructed, mu, logvar = model(images)
    loss = loss_function(reconstructed, images, mu, logvar)
    test_loss += loss.item()
    if batch_idx == 0:
      comparison = torch.cat([images[:5], reconstructed.view(batch_size, 1, 28, 28)[:5]])
      save_image(comparison.cpu(), sample_dir+'/reconstruction_' + str(epoch)+ '.png', nrow=5)

    
  print("==========================>Epochs {}, Average Loss for Testing: {:.3f} ".format(epoch, test_loss/ len(test_loader.dataset)))

# %%
# Main function
for epoch in range(1, epochs + 1):
  train(epoch)
  test(epoch)
  with torch.no_grad():
    #Get rid of encoder and sample z from the gaussian distribution and feed it to decoder to generate 64 sample images
    sample = torch.randn(64, 20).to(device)
    generated = model.decode(sample).cpu()
    save_image(generated.view(64, 1, 28, 28), sample_dir+'/sample_' +  str(epoch) + '.png' )
# Out:
# Training epochs: 1 [Batch 0/469]	Loss: 549.412
# Training epochs: 1 [Batch 100/469]	Loss: 194.161
# Training epochs: 1 [Batch 200/469]	Loss: 160.623
# Training epochs: 1 [Batch 300/469]	Loss: 139.082
# Training epochs: 1 [Batch 400/469]	Loss: 117.197
# ==========================>Epochs 1, Average Loss for Training: 163.583
# ==========================>Epochs 1, Average Loss for Testing: 117.813
# Training epochs: 2 [Batch 0/469]	Loss: 116.225
# Training epochs: 2 [Batch 100/469]	Loss: 116.435
# Training epochs: 2 [Batch 200/469]	Loss: 112.324
# Training epochs: 2 [Batch 300/469]	Loss: 107.715
# Training epochs: 2 [Batch 400/469]	Loss: 104.583
# ==========================>Epochs 2, Average Loss for Training: 110.158
# ==========================>Epochs 2, Average Loss for Testing: 102.524
# Training epochs: 3 [Batch 0/469]	Loss: 105.166
# Training epochs: 3 [Batch 100/469]	Loss: 101.726
# Training epochs: 3 [Batch 200/469]	Loss: 103.773
# Training epochs: 3 [Batch 300/469]	Loss: 100.210
# Training epochs: 3 [Batch 400/469]	Loss: 100.751
# ==========================>Epochs 3, Average Loss for Training: 101.011
# ==========================>Epochs 3, Average Loss for Testing: 97.838
# Training epochs: 4 [Batch 0/469]	Loss: 101.309
# Training epochs: 4 [Batch 100/469]	Loss: 101.296
# Training epochs: 4 [Batch 200/469]	Loss: 95.138
# Training epochs: 4 [Batch 300/469]	Loss: 99.501
# Training epochs: 4 [Batch 400/469]	Loss: 97.506
# ==========================>Epochs 4, Average Loss for Training: 97.517
# ==========================>Epochs 4, Average Loss for Testing: 95.572
# Training epochs: 5 [Batch 0/469]	Loss: 95.381
# Training epochs: 5 [Batch 100/469]	Loss: 95.612
# Training epochs: 5 [Batch 200/469]	Loss: 97.778
# Training epochs: 5 [Batch 300/469]	Loss: 95.651
# Training epochs: 5 [Batch 400/469]	Loss: 95.885
# ==========================>Epochs 5, Average Loss for Training: 95.488
# ==========================>Epochs 5, Average Loss for Testing: 94.177
# Training epochs: 6 [Batch 0/469]	Loss: 94.566
# Training epochs: 6 [Batch 100/469]	Loss: 95.807
# Training epochs: 6 [Batch 200/469]	Loss: 94.079
# Training epochs: 6 [Batch 300/469]	Loss: 96.583
# Training epochs: 6 [Batch 400/469]	Loss: 95.436
# ==========================>Epochs 6, Average Loss for Training: 94.170
# ==========================>Epochs 6, Average Loss for Testing: 93.579
# Training epochs: 7 [Batch 0/469]	Loss: 91.789
# Training epochs: 7 [Batch 100/469]	Loss: 87.031
# Training epochs: 7 [Batch 200/469]	Loss: 92.151
# Training epochs: 7 [Batch 300/469]	Loss: 92.661
# Training epochs: 7 [Batch 400/469]	Loss: 91.887
# ==========================>Epochs 7, Average Loss for Training: 93.187
# ==========================>Epochs 7, Average Loss for Testing: 92.401
# Training epochs: 8 [Batch 0/469]	Loss: 93.613
# Training epochs: 8 [Batch 100/469]	Loss: 91.405
# Training epochs: 8 [Batch 200/469]	Loss: 91.741
# Training epochs: 8 [Batch 300/469]	Loss: 90.944
# Training epochs: 8 [Batch 400/469]	Loss: 89.738
# ==========================>Epochs 8, Average Loss for Training: 92.427
# ==========================>Epochs 8, Average Loss for Testing: 91.728
# Training epochs: 9 [Batch 0/469]	Loss: 96.196
# Training epochs: 9 [Batch 100/469]	Loss: 91.204
# Training epochs: 9 [Batch 200/469]	Loss: 92.397
# Training epochs: 9 [Batch 300/469]	Loss: 91.306
# Training epochs: 9 [Batch 400/469]	Loss: 91.518
# ==========================>Epochs 9, Average Loss for Training: 91.891
# ==========================>Epochs 9, Average Loss for Testing: 91.334
# Training epochs: 10 [Batch 0/469]	Loss: 88.907
# Training epochs: 10 [Batch 100/469]	Loss: 92.020
# Training epochs: 10 [Batch 200/469]	Loss: 91.118
# Training epochs: 10 [Batch 300/469]	Loss: 92.287
# Training epochs: 10 [Batch 400/469]	Loss: 92.344
# ==========================>Epochs 10, Average Loss for Training: 91.378
# ==========================>Epochs 10, Average Loss for Testing: 90.943
# Training epochs: 11 [Batch 0/469]	Loss: 92.844
# Training epochs: 11 [Batch 100/469]	Loss: 94.263
# Training epochs: 11 [Batch 200/469]	Loss: 91.134
# Training epochs: 11 [Batch 300/469]	Loss: 92.621
# Training epochs: 11 [Batch 400/469]	Loss: 90.157
# ==========================>Epochs 11, Average Loss for Training: 90.993
# ==========================>Epochs 11, Average Loss for Testing: 90.575
# Training epochs: 12 [Batch 0/469]	Loss: 92.849
# Training epochs: 12 [Batch 100/469]	Loss: 91.102
# Training epochs: 12 [Batch 200/469]	Loss: 87.065
# Training epochs: 12 [Batch 300/469]	Loss: 88.739
# Training epochs: 12 [Batch 400/469]	Loss: 92.989
# ==========================>Epochs 12, Average Loss for Training: 90.643
# ==========================>Epochs 12, Average Loss for Testing: 90.362
# Training epochs: 13 [Batch 0/469]	Loss: 92.512
# Training epochs: 13 [Batch 100/469]	Loss: 91.135
# Training epochs: 13 [Batch 200/469]	Loss: 85.780
# Training epochs: 13 [Batch 300/469]	Loss: 89.425
# Training epochs: 13 [Batch 400/469]	Loss: 91.478
# ==========================>Epochs 13, Average Loss for Training: 90.390
# ==========================>Epochs 13, Average Loss for Testing: 90.216
# Training epochs: 14 [Batch 0/469]	Loss: 86.594
# Training epochs: 14 [Batch 100/469]	Loss: 88.884
# Training epochs: 14 [Batch 200/469]	Loss: 87.266
# Training epochs: 14 [Batch 300/469]	Loss: 89.153
# Training epochs: 14 [Batch 400/469]	Loss: 89.570
# ==========================>Epochs 14, Average Loss for Training: 90.111
# ==========================>Epochs 14, Average Loss for Testing: 90.057
# Training epochs: 15 [Batch 0/469]	Loss: 89.118
# Training epochs: 15 [Batch 100/469]	Loss: 94.510
# Training epochs: 15 [Batch 200/469]	Loss: 87.239
# Training epochs: 15 [Batch 300/469]	Loss: 88.788
# Training epochs: 15 [Batch 400/469]	Loss: 88.619
# ==========================>Epochs 15, Average Loss for Training: 89.882
# ==========================>Epochs 15, Average Loss for Testing: 89.793
# Training epochs: 16 [Batch 0/469]	Loss: 92.426
# Training epochs: 16 [Batch 100/469]	Loss: 86.425
# Training epochs: 16 [Batch 200/469]	Loss: 85.971
# Training epochs: 16 [Batch 300/469]	Loss: 89.233
# Training epochs: 16 [Batch 400/469]	Loss: 90.451
# ==========================>Epochs 16, Average Loss for Training: 89.696
# ==========================>Epochs 16, Average Loss for Testing: 89.673
# Training epochs: 17 [Batch 0/469]	Loss: 87.245
# Training epochs: 17 [Batch 100/469]	Loss: 92.415
# Training epochs: 17 [Batch 200/469]	Loss: 91.063
# Training epochs: 17 [Batch 300/469]	Loss: 88.706
# Training epochs: 17 [Batch 400/469]	Loss: 90.668
# ==========================>Epochs 17, Average Loss for Training: 89.553
# ==========================>Epochs 17, Average Loss for Testing: 89.458
# Training epochs: 18 [Batch 0/469]	Loss: 87.709
# Training epochs: 18 [Batch 100/469]	Loss: 85.637
# Training epochs: 18 [Batch 200/469]	Loss: 89.253
# Training epochs: 18 [Batch 300/469]	Loss: 86.846
# Training epochs: 18 [Batch 400/469]	Loss: 87.794
# ==========================>Epochs 18, Average Loss for Training: 89.339
# ==========================>Epochs 18, Average Loss for Testing: 89.119
# Training epochs: 19 [Batch 0/469]	Loss: 87.852
# Training epochs: 19 [Batch 100/469]	Loss: 90.177
# Training epochs: 19 [Batch 200/469]	Loss: 91.291
# Training epochs: 19 [Batch 300/469]	Loss: 89.037
# Training epochs: 19 [Batch 400/469]	Loss: 87.846
# ==========================>Epochs 19, Average Loss for Training: 89.183
# ==========================>Epochs 19, Average Loss for Testing: 89.173
# Training epochs: 20 [Batch 0/469]	Loss: 86.304
# Training epochs: 20 [Batch 100/469]	Loss: 89.715
# Training epochs: 20 [Batch 200/469]	Loss: 88.461
# Training epochs: 20 [Batch 300/469]	Loss: 89.274
# Training epochs: 20 [Batch 400/469]	Loss: 87.991
# ==========================>Epochs 20, Average Loss for Training: 89.039
# ==========================>Epochs 20, Average Loss for Testing: 88.988
# Training epochs: 21 [Batch 0/469]	Loss: 91.627
# Training epochs: 21 [Batch 100/469]	Loss: 89.951
# Training epochs: 21 [Batch 200/469]	Loss: 89.700
# Training epochs: 21 [Batch 300/469]	Loss: 87.493
# Training epochs: 21 [Batch 400/469]	Loss: 87.723
# ==========================>Epochs 21, Average Loss for Training: 88.904
# ==========================>Epochs 21, Average Loss for Testing: 89.034
# Training epochs: 22 [Batch 0/469]	Loss: 88.300
# Training epochs: 22 [Batch 100/469]	Loss: 88.341
# Training epochs: 22 [Batch 200/469]	Loss: 89.178
# Training epochs: 22 [Batch 300/469]	Loss: 90.214
# Training epochs: 22 [Batch 400/469]	Loss: 86.351
# ==========================>Epochs 22, Average Loss for Training: 88.801
# ==========================>Epochs 22, Average Loss for Testing: 88.948
# Training epochs: 23 [Batch 0/469]	Loss: 86.924
# Training epochs: 23 [Batch 100/469]	Loss: 89.396
# Training epochs: 23 [Batch 200/469]	Loss: 90.025
# Training epochs: 23 [Batch 300/469]	Loss: 85.401
# Training epochs: 23 [Batch 400/469]	Loss: 93.167
# ==========================>Epochs 23, Average Loss for Training: 88.717
# ==========================>Epochs 23, Average Loss for Testing: 88.804
# Training epochs: 24 [Batch 0/469]	Loss: 87.894
# Training epochs: 24 [Batch 100/469]	Loss: 87.767
# Training epochs: 24 [Batch 200/469]	Loss: 87.697
# Training epochs: 24 [Batch 300/469]	Loss: 88.890
# Training epochs: 24 [Batch 400/469]	Loss: 85.048
# ==========================>Epochs 24, Average Loss for Training: 88.584
# ==========================>Epochs 24, Average Loss for Testing: 88.686
# Training epochs: 25 [Batch 0/469]	Loss: 82.942
# Training epochs: 25 [Batch 100/469]	Loss: 85.591
# Training epochs: 25 [Batch 200/469]	Loss: 91.074
# Training epochs: 25 [Batch 300/469]	Loss: 91.142
# Training epochs: 25 [Batch 400/469]	Loss: 85.187
# ==========================>Epochs 25, Average Loss for Training: 88.478
# ==========================>Epochs 25, Average Loss for Testing: 88.564
# Training epochs: 26 [Batch 0/469]	Loss: 84.774
# Training epochs: 26 [Batch 100/469]	Loss: 90.214
# Training epochs: 26 [Batch 200/469]	Loss: 83.940
# Training epochs: 26 [Batch 300/469]	Loss: 88.307
# Training epochs: 26 [Batch 400/469]	Loss: 90.027
# ==========================>Epochs 26, Average Loss for Training: 88.370
# ==========================>Epochs 26, Average Loss for Testing: 88.474
# Training epochs: 27 [Batch 0/469]	Loss: 89.689
# Training epochs: 27 [Batch 100/469]	Loss: 86.596
# Training epochs: 27 [Batch 200/469]	Loss: 88.147
# Training epochs: 27 [Batch 300/469]	Loss: 91.147
# Training epochs: 27 [Batch 400/469]	Loss: 86.635
# ==========================>Epochs 27, Average Loss for Training: 88.273
# ==========================>Epochs 27, Average Loss for Testing: 88.701
# Training epochs: 28 [Batch 0/469]	Loss: 87.296
# Training epochs: 28 [Batch 100/469]	Loss: 88.243
# Training epochs: 28 [Batch 200/469]	Loss: 90.256
# Training epochs: 28 [Batch 300/469]	Loss: 88.430
# Training epochs: 28 [Batch 400/469]	Loss: 87.790
# ==========================>Epochs 28, Average Loss for Training: 88.201
# ==========================>Epochs 28, Average Loss for Testing: 88.349
# Training epochs: 29 [Batch 0/469]	Loss: 84.824
# Training epochs: 29 [Batch 100/469]	Loss: 88.069
# Training epochs: 29 [Batch 200/469]	Loss: 88.660
# Training epochs: 29 [Batch 300/469]	Loss: 87.843
# Training epochs: 29 [Batch 400/469]	Loss: 88.610
# ==========================>Epochs 29, Average Loss for Training: 88.116
# ==========================>Epochs 29, Average Loss for Testing: 88.221
# Training epochs: 30 [Batch 0/469]	Loss: 87.210
# Training epochs: 30 [Batch 100/469]	Loss: 86.082
# Training epochs: 30 [Batch 200/469]	Loss: 88.897
# Training epochs: 30 [Batch 300/469]	Loss: 89.235
# Training epochs: 30 [Batch 400/469]	Loss: 85.538
# ==========================>Epochs 30, Average Loss for Training: 87.997
# ==========================>Epochs 30, Average Loss for Testing: 88.355
# Training epochs: 31 [Batch 0/469]	Loss: 86.153
# Training epochs: 31 [Batch 100/469]	Loss: 84.873
# Training epochs: 31 [Batch 200/469]	Loss: 87.864
# Training epochs: 31 [Batch 300/469]	Loss: 87.166
# Training epochs: 31 [Batch 400/469]	Loss: 84.543
# ==========================>Epochs 31, Average Loss for Training: 87.986
# ==========================>Epochs 31, Average Loss for Testing: 88.081
# Training epochs: 32 [Batch 0/469]	Loss: 88.230
# Training epochs: 32 [Batch 100/469]	Loss: 86.270
# Training epochs: 32 [Batch 200/469]	Loss: 87.247
# Training epochs: 32 [Batch 300/469]	Loss: 87.477
# Training epochs: 32 [Batch 400/469]	Loss: 88.588
# ==========================>Epochs 32, Average Loss for Training: 87.890
# ==========================>Epochs 32, Average Loss for Testing: 88.108
# Training epochs: 33 [Batch 0/469]	Loss: 87.010
# Training epochs: 33 [Batch 100/469]	Loss: 86.998
# Training epochs: 33 [Batch 200/469]	Loss: 82.772
# Training epochs: 33 [Batch 300/469]	Loss: 86.710
# Training epochs: 33 [Batch 400/469]	Loss: 87.401
# ==========================>Epochs 33, Average Loss for Training: 87.801
# ==========================>Epochs 33, Average Loss for Testing: 88.148
# Training epochs: 34 [Batch 0/469]	Loss: 89.122
# Training epochs: 34 [Batch 100/469]	Loss: 89.930
# Training epochs: 34 [Batch 200/469]	Loss: 85.362
# Training epochs: 34 [Batch 300/469]	Loss: 81.998
# Training epochs: 34 [Batch 400/469]	Loss: 88.082
# ==========================>Epochs 34, Average Loss for Training: 87.728
# ==========================>Epochs 34, Average Loss for Testing: 88.035
# Training epochs: 35 [Batch 0/469]	Loss: 87.138
# Training epochs: 35 [Batch 100/469]	Loss: 90.752
# Training epochs: 35 [Batch 200/469]	Loss: 86.640
# Training epochs: 35 [Batch 300/469]	Loss: 89.006
# Training epochs: 35 [Batch 400/469]	Loss: 84.672
# ==========================>Epochs 35, Average Loss for Training: 87.715
# ==========================>Epochs 35, Average Loss for Testing: 88.049
# Training epochs: 36 [Batch 0/469]	Loss: 85.752
# Training epochs: 36 [Batch 100/469]	Loss: 87.320
# Training epochs: 36 [Batch 200/469]	Loss: 84.944
# Training epochs: 36 [Batch 300/469]	Loss: 84.128
# Training epochs: 36 [Batch 400/469]	Loss: 89.616
# ==========================>Epochs 36, Average Loss for Training: 87.620
# ==========================>Epochs 36, Average Loss for Testing: 88.052
# Training epochs: 37 [Batch 0/469]	Loss: 87.880
# Training epochs: 37 [Batch 100/469]	Loss: 88.812
# Training epochs: 37 [Batch 200/469]	Loss: 91.098
# Training epochs: 37 [Batch 300/469]	Loss: 90.865
# Training epochs: 37 [Batch 400/469]	Loss: 87.918
# ==========================>Epochs 37, Average Loss for Training: 87.590
# ==========================>Epochs 37, Average Loss for Testing: 87.987
# Training epochs: 38 [Batch 0/469]	Loss: 86.499
# Training epochs: 38 [Batch 100/469]	Loss: 87.451
# Training epochs: 38 [Batch 200/469]	Loss: 87.724
# Training epochs: 38 [Batch 300/469]	Loss: 86.333
# Training epochs: 38 [Batch 400/469]	Loss: 87.755
# ==========================>Epochs 38, Average Loss for Training: 87.512
# ==========================>Epochs 38, Average Loss for Testing: 87.779
# Training epochs: 39 [Batch 0/469]	Loss: 84.514
# Training epochs: 39 [Batch 100/469]	Loss: 87.520
# Training epochs: 39 [Batch 200/469]	Loss: 88.146
# Training epochs: 39 [Batch 300/469]	Loss: 86.545
# Training epochs: 39 [Batch 400/469]	Loss: 90.997
# ==========================>Epochs 39, Average Loss for Training: 87.478
# ==========================>Epochs 39, Average Loss for Testing: 88.050
# Training epochs: 40 [Batch 0/469]	Loss: 88.993
# Training epochs: 40 [Batch 100/469]	Loss: 92.052
# Training epochs: 40 [Batch 200/469]	Loss: 89.071
# Training epochs: 40 [Batch 300/469]	Loss: 85.277
# Training epochs: 40 [Batch 400/469]	Loss: 87.551
# ==========================>Epochs 40, Average Loss for Training: 87.404
# ==========================>Epochs 40, Average Loss for Testing: 87.680
# Training epochs: 41 [Batch 0/469]	Loss: 86.520
# Training epochs: 41 [Batch 100/469]	Loss: 85.858
# Training epochs: 41 [Batch 200/469]	Loss: 87.515
# Training epochs: 41 [Batch 300/469]	Loss: 87.051
# Training epochs: 41 [Batch 400/469]	Loss: 89.411
# ==========================>Epochs 41, Average Loss for Training: 87.331
# ==========================>Epochs 41, Average Loss for Testing: 87.828
# Training epochs: 42 [Batch 0/469]	Loss: 84.756
# Training epochs: 42 [Batch 100/469]	Loss: 85.860
# Training epochs: 42 [Batch 200/469]	Loss: 86.929
# Training epochs: 42 [Batch 300/469]	Loss: 86.327
# Training epochs: 42 [Batch 400/469]	Loss: 88.060
# ==========================>Epochs 42, Average Loss for Training: 87.304
# ==========================>Epochs 42, Average Loss for Testing: 87.681
# Training epochs: 43 [Batch 0/469]	Loss: 86.078
# Training epochs: 43 [Batch 100/469]	Loss: 84.542
# Training epochs: 43 [Batch 200/469]	Loss: 90.700
# Training epochs: 43 [Batch 300/469]	Loss: 87.113
# Training epochs: 43 [Batch 400/469]	Loss: 84.598
# ==========================>Epochs 43, Average Loss for Training: 87.250
# ==========================>Epochs 43, Average Loss for Testing: 87.797
# Training epochs: 44 [Batch 0/469]	Loss: 85.522
# Training epochs: 44 [Batch 100/469]	Loss: 88.073
# Training epochs: 44 [Batch 200/469]	Loss: 88.169
# Training epochs: 44 [Batch 300/469]	Loss: 88.117
# Training epochs: 44 [Batch 400/469]	Loss: 90.904
# ==========================>Epochs 44, Average Loss for Training: 87.195
# ==========================>Epochs 44, Average Loss for Testing: 87.624
# Training epochs: 45 [Batch 0/469]	Loss: 86.529
# Training epochs: 45 [Batch 100/469]	Loss: 86.081
# Training epochs: 45 [Batch 200/469]	Loss: 86.873
# Training epochs: 45 [Batch 300/469]	Loss: 87.250
# Training epochs: 45 [Batch 400/469]	Loss: 89.713
# ==========================>Epochs 45, Average Loss for Training: 87.189
# ==========================>Epochs 45, Average Loss for Testing: 87.598
# Training epochs: 46 [Batch 0/469]	Loss: 89.319
# Training epochs: 46 [Batch 100/469]	Loss: 88.567
# Training epochs: 46 [Batch 200/469]	Loss: 84.557
# Training epochs: 46 [Batch 300/469]	Loss: 89.009
# Training epochs: 46 [Batch 400/469]	Loss: 89.888
# ==========================>Epochs 46, Average Loss for Training: 87.097
# ==========================>Epochs 46, Average Loss for Testing: 87.653
# Training epochs: 47 [Batch 0/469]	Loss: 86.666
# Training epochs: 47 [Batch 100/469]	Loss: 88.813
# Training epochs: 47 [Batch 200/469]	Loss: 89.513
# Training epochs: 47 [Batch 300/469]	Loss: 87.428
# Training epochs: 47 [Batch 400/469]	Loss: 90.156
# ==========================>Epochs 47, Average Loss for Training: 87.067
# ==========================>Epochs 47, Average Loss for Testing: 87.515
# Training epochs: 48 [Batch 0/469]	Loss: 84.910
# Training epochs: 48 [Batch 100/469]	Loss: 87.050
# Training epochs: 48 [Batch 200/469]	Loss: 90.608
# Training epochs: 48 [Batch 300/469]	Loss: 88.006
# Training epochs: 48 [Batch 400/469]	Loss: 84.209
# ==========================>Epochs 48, Average Loss for Training: 87.064
# ==========================>Epochs 48, Average Loss for Testing: 87.646
# Training epochs: 49 [Batch 0/469]	Loss: 87.150
# Training epochs: 49 [Batch 100/469]	Loss: 89.039
# Training epochs: 49 [Batch 200/469]	Loss: 87.649
# Training epochs: 49 [Batch 300/469]	Loss: 84.916
# Training epochs: 49 [Batch 400/469]	Loss: 85.625
# ==========================>Epochs 49, Average Loss for Training: 87.014
# ==========================>Epochs 49, Average Loss for Testing: 87.961
# Training epochs: 50 [Batch 0/469]	Loss: 84.293
# Training epochs: 50 [Batch 100/469]	Loss: 87.579
# Training epochs: 50 [Batch 200/469]	Loss: 87.675
# Training epochs: 50 [Batch 300/469]	Loss: 85.116
# Training epochs: 50 [Batch 400/469]	Loss: 86.935
# ==========================>Epochs 50, Average Loss for Training: 86.943
# ==========================>Epochs 50, Average Loss for Testing: 87.447
